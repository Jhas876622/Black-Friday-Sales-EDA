# %% [markdown]
# # ************** BLACK FRIDAY SALES DATA ANALYSIS **************

# %% [markdown]
# Black Friday is a shopping holiday  that takes place on the day after Thanksgiving. It is known for its deep discounts and special deals on a wide range of products, including electronics, home goods, clothing, and more. Many retailers offer special doorbuster deals and extended hours on Black Friday, and it is traditionally one of the busiest shopping days of the year.
#
# This project explores the Black Friday Sales Data to uncover purchasing patterns and insights from various user demographics. The dataset includes multiple details about users, including their age, gender, occupation, and marital status, as well as information about the products they purchased during the Black Friday sale event. Through this project, we will walk through several steps to analyze the dataset, perform in-depth analysis of different columns, and combine multiple factors to gain actionable insights.
#
# ### --> Prerequisites
# Before starting with this project, ensure that you have the following knowledge and tools:
#
# Basic Python: Understanding of Python programming fundamentals.
# Pandas: Familiarity with pandas for data manipulation and analysis.
# Matplotlib & Seaborn: Basic knowledge of these libraries for data visualization (e.g., bar plots, pie charts, box plots).
# Jupyter Notebook: Ability to work with Jupyter Notebook for running Python code interactively.
# Basic Data Analysis: Understanding how to clean data, handle missing values, and perform basic exploratory data analysis (EDA).
#
# ### --> Dataset Details
# * Dataset Name: Black Friday Sales Data
# * Dataset Size: 23 MB CSV file, containing over 537,000 rows and 12 columns.
# * Columns: User ID, Product ID, Gender, Age, Occupation, City Category, Stay in Current City Years, Marital Status, Product Categories, and Purchase amount.
# * Source: The dataset can be downloaded from here.
#
#
# ### Project Steps Overview:
#
# #### --> Walkthrough of the Dataset
# * Goal: Load the dataset, inspect its structure, and understand the contents.
# * Actions:
# We begin by loading the Black Friday Sales dataset into a pandas DataFrame.
# We examine the dataset’s structure and look for any missing values or discrepancies.
# We perform a basic overview using df.info() to see the types of columns and the number of non-null entries.
# Dataset link: Black Friday Sales Dataset
#
# #### --> Analyzing Columns
# * Goal: Dive deeper into each column to understand their distributions and relevance.
# * Actions:
# We focus on key columns like Gender, Age, Marital_Status, Product_Category, and Purchase.
# We handle missing data by dropping columns that are too sparse, like Product_Category_2 and Product_Category_3.
# We focus on understanding the unique values in various columns to gain an overview of the data. Specifically, we used unique() and nunique() functions to extract meaningful information from individual columns.
#
# #### --> Analyzing Gender
# * Goal: Analyze the gender distribution of the customers and examine if there are any purchasing trends based on gender.
# * Actions:
# Data Imbalance: A significantly higher number of male customers compared to female customers in the dataset.
# Groupby Function: By using the groupby() function, we grouped the data by gender and found that male customers were responsible for a larger portion of the purchases.
#
# #### --> Analyzing Age & Marital Status
# * Goal: Investigate how age groups and marital status affect purchasing behavior.
# * Actions:
# We categorize users by age group and marital status, examining which groups tend to spend more during Black Friday sales.
#
# #### --> Multi Column Analysis
# * Goal: Combine multiple columns to analyze more complex relationships and derive insights from combinations of factors.
# * Actions:
# We combine Age, Marital Status, and Gender to see if purchasing patterns vary when users' characteristics are combined.
# By combining both factors with visualizations like pie charts and bar plots, we gained a clearer understanding of purchasing behavior across different age groups and marital statuses.
#
# #### --> Occupation and Products Analysis
# * Goal: Analyze how occupation influences purchasing behavior and which product categories are most popular among different occupations.
# * Actions:
# We analyzed the Occupation, Product_ID, and Product_Category_1 columns. We aimed to understand the relationship between a customer’s occupation and the products they are most likely to purchase.
#
# #### --> Combining Gender & Marital Status
# * Goal: Further investigate the combined effects of gender and marital status on purchasing behavior.
# * Actions:
# The final analysis combined Gender and Marital Status to examine if there was any significant relationship between these two factors and purchasing behavior.
# We used Seaborn’s count plot to visualize how the combination of gender and marital status influences purchases. This allowed us to easily see which combinations were more likely to make purchases.
#
#
# ## Conclusion
# This project not only helps us understand the purchasing behavior of Black Friday shoppers but also provides insights into the influence of demographic factors like gender, age, marital status, and occupation on buying patterns. By using the Black Friday sales dataset, we walk through the process of cleaning the data, analyzing individual columns, and combining multiple features to uncover hidden patterns.
#
# You can follow along with the steps mentioned above and analyze the dataset yourself. Each step has its corresponding GitHub repository link where you can find the code and details for a more hands-on approach.

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# # Analysing Column

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column, ":" ,df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# # Analysing Gender

# %%
for column in df.columns:
    print(df[column].nunique(), "\t: ", column)
# Out:
# 5891 	:  User_ID
# 3623 	:  Product_ID
# 2 	:  Gender
# 7 	:  Age
# 21 	:  Occupation
# 3 	:  City_Category
# 5 	:  Stay_In_Current_City_Years
# 2 	:  Marital_Status
# 18 	:  Product_Category_1
# 17959 	:  Purchase

# %%
len(df[df['Gender'] == 'M']) , len(df[df['Gender'] == 'F']) # Number of males and female purchasing
# Out:
# (405380, 132197)

# %%
data = pd.DataFrame({'Ratio' : [len(df[df['Gender'] == 'M']), len(df[df['Gender'] == 'F'])]}, 
                    index = ['Male', 'Female'])

data.plot.pie(y = 'Ratio', figsize = (6,6), autopct = "%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind = 'pie', 
                                 autopct = "%.1f",
                                 title = 'Gender Ratio',
                                 figsize = (6,6))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size().plot(kind = 'bar', 
                                 figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Age').size().plot(kind = 'bar',figsize = (12,6), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i, df[df['Age'] == i]['Product_ID'].nunique()])
    
data = pd.DataFrame(lst , columns = ['Age','Products'])

# %%
data.plot.bar(x = 'Age', figsize = (8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (12, 6), title = 'Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df['Purchase'] = df['Purchase'].astype(float)  # or astype(int) if they should be integers

# %%
print(df['Purchase'].head())
print(df['Purchase'].dtype)
# Out:
# 0     8370.0
# 1    15200.0
# 2     1422.0
# 3     1057.0
# 4     7969.0
# Name: Purchase, dtype: float64
# float64

# %%
# Alternative approach
result = df.groupby('Age')['Purchase'].agg('mean')
result.plot(kind='bar', figsize=(12, 6), title='Amount Spent by Age')
# Out:
# <Axes: title={'center': 'Amount Spent by Age'}, xlabel='Age'>

# %%
result.plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('Gender').size().plot(kind = 'pie' , autopct= '%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# # Multi Column Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3    8370.0
# 1                          2               0                   1   15200.0
# 2                          2               0                  12    1422.0
# 3                          2               0                  12    1057.0
# 4                         4+               0                   8    7969.0

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Age", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Gender", hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Gender", hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = "Marital_Status", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Age', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Marital_Status', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'City_Category', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")

# %%
sns.countplot(data = df , x = 'Stay_In_Current_City_Years',hue = 'Stay_In_Current_City_Years',palette = 'bright',legend = False)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years',hue = 'Gender',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years',hue = 'Marital_Status',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years',hue = 'City_Category',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category' , hue = 'Age',data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind = 'pie', autopct = "%.1f")
# Out:
# <Axes: >

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'pie',autopct = "%.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(data = df , x = 'Occupation',hue = 'Occupation',palette = 'viridis',legend = False)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
print(df['Purchase'].dtype)
print(df['Purchase'].head())
# Out:
# float64
# 0     8370.0
# 1    15200.0
# 2     1422.0
# 3     1057.0
# 4     7969.0
# Name: Purchase, dtype: float64

# %%
df['Purchase'] = pd.to_numeric(df['Purchase'], errors='coerce')

# %%
df = df.dropna(subset=['Purchase'])

# %%
# Convert to numeric explicitly first
df['Purchase_num'] = pd.to_numeric(df['Purchase'], errors='coerce')

# Now group using the new column
result = df.groupby('Occupation')['Purchase_num'].mean().sort_values()
result.plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase_num'].mean().sort_values()
# Out:
# Occupation
# 9     8714.335934
# 19    8754.249162
# 20    8881.099514
# 1     9017.703095
# 2     9025.938982
# 10    9052.836410
# 0     9186.946726
# 18    9233.671418
# 3     9238.077277
# 4     9279.026742
# 11    9299.467190
# 6     9336.378620
# 5     9388.848978
# 13    9424.449391
# 16    9457.133118
# 7     9502.175276
# 14    9568.536426
# 8     9576.508530
# 15    9866.239925
# 12    9883.052460
# 17    9906.378997
# Name: Purchase_num, dtype: float64

# %%
sns.countplot(x= 'Occupation' , hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x= 'Occupation' , hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df['Product_Category_1_num'] =  pd.to_numeric(df['Product_Category_1'], errors ='coerce')
result = df.groupby('Product_Category_1_num')['Purchase'].mean().sort_values().plot(kind = 'bar')
result
# Out:
# <Axes: xlabel='Product_Category_1_num'>

# %%
df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df['Purchase_1'] = pd.to_numeric(df['Purchase'],errors ='coerce')
result = df.groupby('Product_ID')['Purchase_1'].mean().nlargest(10).sort_values().plot(kind = 'bar')
result
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x = 'Product_Category_1',hue = 'Marital_Status' , data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1',hue = 'Gender' , data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# # Combining Age & Marital Status

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3    8370.0
# 1                          2               0                   1   15200.0
# 2                          2               0                  12    1422.0
# 3                          2               0                  12    1057.0
# 4                         4+               0                   8    7969.0
#
#    Purchase_num  Product_Category_1_num  Purchase_1
# 0        8370.0                       3      8370.0
# 1       15200.0                       1     15200.0
# 2        1422.0                      12      1422.0
# 3        1057.0                      12      1057.0
# 4        7969.0                       8      7969.0

# %%
l = []
for i in range (len(df)):
    l.append(df['Gender'][i] +"_"+ str(df['Marital_Status'][i]))

df['MaritalGender'] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3    8370.0
# 1                          2               0                   1   15200.0
# 2                          2               0                  12    1422.0
# 3                          2               0                  12    1057.0
# 4                         4+               0                   8    7969.0
#
#    Purchase_num  Product_Category_1_num  Purchase_1 MaritalGender
# 0        8370.0                       3      8370.0           F_0
# 1       15200.0                       1     15200.0           F_0
# 2        1422.0                      12      1422.0           F_0
# 3        1057.0                      12      1057.0           F_0
# 4        7969.0                       8      7969.0           M_0

# %%
sns.countplot(x = df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x = df['Age'],hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = df['Product_Category_1'],hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'],hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'],hue = df['MaritalGender'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# ### Men unmarried spend the most in black friday sales then Men married then Female unmarried then female married.
